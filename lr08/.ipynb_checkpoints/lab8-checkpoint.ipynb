# %%
import numpy as np
import matplotlib.pyplot as plt 
import math
import sympy as sp

# %%
x = np.linspace(1, 115, 1000)
y = np.linspace(1, 115, 1000)
X, Y = np.meshgrid(x, y)
Z = X * Y + 50 / X + 50 / Y
fig, ax = plt.subplots()
cs = ax.contour(X, Y, Z)

#x = np.linspace(-5, -1)
#y = np.linspace(-5, -1)
#X, Y = np.meshgrid(x, y)
#Z = X * Y + 50 / X + 50 / Y
#cs = ax.contour(X, Y, Z)

# ax.clabel(cs, cs.levels, inline=True, fontsize=10)
# plt.xlabel('x'); plt.ylabel('y')
# plt.show()
