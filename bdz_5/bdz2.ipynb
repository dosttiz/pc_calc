# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from matplotlib import cm
import math

# %%
x = sp.Symbol('x')
y = sp.Symbol('y')
ie = x / (x + y) <= 1

# %%
sp.solveset(ie, x)
# Out:
# ConditionSet(x, x/(x + y) <= 1, Complexes)
